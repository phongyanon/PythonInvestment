# %%
import os, csv
from dotenv import load_dotenv
import pandas as pd
import time

from datetime import datetime, timedelta
import yfinance as yf
yf.pdr_override()

import calendar
import pandas as pd
import pandas_ta as ta
import numpy as np

from pandas_datareader import data as pdr
from alpha_vantage.timeseries import TimeSeries
from alpha_vantage.foreignexchange import ForeignExchange
load_dotenv()
# Out:
# True

# %%
API_KEYS = os.getenv('ALPHA_KEYS')
cc = ForeignExchange(key=API_KEYS)
ts = TimeSeries(key=API_KEYS, output_format='pandas')

# %%
bars, _ = ts.get_intraday(symbol="EURUSD",interval="15min", outputsize='compact')
bars
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2022-07-22 02:45:00   1.0195   1.0195  1.0192    1.0194        0.0
# 2022-07-22 02:30:00   1.0188   1.0195  1.0182    1.0195        0.0
# 2022-07-22 02:15:00   1.0185   1.0193  1.0181    1.0187        0.0
# 2022-07-22 02:00:00   1.0190   1.0194  1.0183    1.0185        0.0
# 2022-07-22 01:45:00   1.0185   1.0191  1.0183    1.0190        0.0
# ...                      ...      ...     ...       ...        ...
# 2022-07-21 03:00:00   1.0217   1.0218  1.0200    1.0205        0.0
# 2022-07-21 02:45:00   1.0215   1.0221  1.0206    1.0217        0.0
# 2022-07-21 02:30:00   1.0229   1.0229  1.0213    1.0216        0.0
# 2022-07-21 02:15:00   1.0223   1.0231  1.0217    1.0229        0.0
# 2022-07-21 02:00:00   1.0224   1.0227  1.0219    1.0223        0.0
#
# [100 rows x 5 columns]

# %%
EURUSD = pdr.get_data_yahoo("EURUSD=x", start='2022-07-21', end='2022-07-22', interval='15m')
EURUSD
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                Open      High       Low     Close  Adj Close  \
# Datetime
# 2022-07-20 18:00:00+01:00  1.019160  1.019160  1.017501  1.018123   1.018123
# 2022-07-20 18:15:00+01:00  1.017915  1.017915  1.016984  1.016984   1.016984
# 2022-07-20 18:30:00+01:00  1.016880  1.017398  1.016260  1.016467   1.016467
# 2022-07-20 18:45:00+01:00  1.016570  1.016777  1.015847  1.015950   1.015950
# 2022-07-20 19:00:00+01:00  1.016260  1.016984  1.016260  1.016880   1.016880
# ...                             ...       ...       ...       ...        ...
# 2022-07-21 16:45:00+01:00  1.020825  1.020825  1.020304  1.020304   1.020304
# 2022-07-21 17:00:00+01:00  1.019784  1.019888  1.018641  1.018745   1.018745
# 2022-07-21 17:15:00+01:00  1.018952  1.019368  1.018434  1.019264   1.019264
# 2022-07-21 17:30:00+01:00  1.019264  1.019264  1.018019  1.018019   1.018019
# ...

# %%
tickers = ['EURUSD=x']
for ticker in tickers:
    ticker_yahoo = yf.Ticker(ticker)
    data = ticker_yahoo.history(period='2d', interval='15m')
    last_quote = data['Close'].iloc[-1]
    print(data)
# Out:
#                                Open      High       Low     Close  Volume  \
# Datetime
# 2022-07-21 00:00:00+01:00  1.018434  1.018745  1.018330  1.018537       0
# 2022-07-21 00:15:00+01:00  1.018537  1.018537  1.018019  1.018123       0
