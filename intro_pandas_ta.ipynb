# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import yfinance as yf

# %%
start = '2020-06-01'
end = '2021-06-01'

# %%
data = pd.DataFrame()
data = df.ta.ticker('tsla', period = '2y', interval = '1h')

# %%
df = data.copy()

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# 2019-09-09 09:30:00-04:00  46.049461  46.751999  45.883999  46.480000
# 2019-09-09 10:30:00-04:00  46.479599  46.535999  46.220001  46.461998
# 2019-09-09 11:30:00-04:00  46.457001  46.686279  46.079998  46.120003
# 2019-09-09 12:30:00-04:00  46.115639  46.280201  45.993000  46.117001
# 2019-09-09 13:30:00-04:00  46.120003  46.191879  45.920002  45.995998
#
#                             Volume  Dividends  Stock Splits
# 2019-09-09 09:30:00-04:00  1924480          0           0.0
# 2019-09-09 10:30:00-04:00   623222          0           0.0
# 2019-09-09 11:30:00-04:00   679639          0           0.0
# 2019-09-09 12:30:00-04:00   394387          0           0.0
# 2019-09-09 13:30:00-04:00   328890          0           0.0

# %%
# df.ta.macd()
df.ta.macd(fast=10, slow=20, signal=5, append=True).plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# 2019-09-09 09:30:00-04:00   46.049461   46.751999   45.883999   46.480000
# 2019-09-09 10:30:00-04:00   46.479599   46.535999   46.220001   46.461998
# 2019-09-09 11:30:00-04:00   46.457001   46.686279   46.079998   46.120003
# 2019-09-09 12:30:00-04:00   46.115639   46.280201   45.993000   46.117001
# 2019-09-09 13:30:00-04:00   46.120003   46.191879   45.920002   45.995998
# ...                               ...         ...         ...         ...
# 2021-09-07 11:30:00-04:00  750.283203  753.159973  749.130005  752.230103
# 2021-09-07 12:30:00-04:00  752.300415  753.349915  750.030029  752.299927
# 2021-09-07 13:30:00-04:00  752.140015  754.839600  751.727173  752.979980
# 2021-09-07 14:30:00-04:00  752.849976  755.599976  752.309998  753.140015
# 2021-09-07 15:30:00-04:00  753.039978  753.989990  751.289978  752.739990
#
#                             Volume  Dividends  Stock Splits  MACD_10_20_5  \
# ...

# %%
df.ta.indicators()
# Out:
# Pandas TA - Technical Analysis Indicators - v0.3.14b0
# Total Indicators & Utilities: 205
# Abbreviations:
# ...

# %%
df.ta.rsi(length=14, append=True)
# Out:
# 2019-09-09 09:30:00-04:00          NaN
# 2019-09-09 10:30:00-04:00          NaN
# 2019-09-09 11:30:00-04:00          NaN
# 2019-09-09 12:30:00-04:00          NaN
# 2019-09-09 13:30:00-04:00          NaN
#                                ...
# 2021-09-07 11:30:00-04:00    68.304410
# 2021-09-07 12:30:00-04:00    68.351215
# 2021-09-07 13:30:00-04:00    68.833932
# 2021-09-07 14:30:00-04:00    68.953937
# 2021-09-07 15:30:00-04:00    68.246555
# Name: RSI_14, Length: 3515, dtype: float64

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# 2019-09-09 09:30:00-04:00   46.049461   46.751999   45.883999   46.480000
# 2019-09-09 10:30:00-04:00   46.479599   46.535999   46.220001   46.461998
# 2019-09-09 11:30:00-04:00   46.457001   46.686279   46.079998   46.120003
# 2019-09-09 12:30:00-04:00   46.115639   46.280201   45.993000   46.117001
# 2019-09-09 13:30:00-04:00   46.120003   46.191879   45.920002   45.995998
# ...                               ...         ...         ...         ...
# 2021-09-07 11:30:00-04:00  750.283203  753.159973  749.130005  752.230103
# 2021-09-07 12:30:00-04:00  752.300415  753.349915  750.030029  752.299927
# 2021-09-07 13:30:00-04:00  752.140015  754.839600  751.727173  752.979980
# 2021-09-07 14:30:00-04:00  752.849976  755.599976  752.309998  753.140015
# 2021-09-07 15:30:00-04:00  753.039978  753.989990  751.289978  752.739990
#
#                             Volume  Dividends  Stock Splits  MACD_10_20_5  \
# ...

# %%
df = data.copy()

# %%
df.ta.percent_return(cumulative=True).plot()
# Out:
# <AxesSubplot:>

# %%
 costom_test = ta.Strategy(
     name='test_strategy',
     description='ris, MACD',
     ta = [
         {"kind": "rsi", "length": 14},
         {"kind": "macd", "fast": 16, "slow": 21}
     ]
 )

# %%
df.ta.strategy(costom_test)

# %%
df
# Out:
#                                  Open        High         Low       Close  \
# 2019-09-09 09:30:00-04:00   46.049461   46.751999   45.883999   46.480000
# 2019-09-09 10:30:00-04:00   46.479599   46.535999   46.220001   46.461998
# 2019-09-09 11:30:00-04:00   46.457001   46.686279   46.079998   46.120003
# 2019-09-09 12:30:00-04:00   46.115639   46.280201   45.993000   46.117001
# 2019-09-09 13:30:00-04:00   46.120003   46.191879   45.920002   45.995998
# ...                               ...         ...         ...         ...
# 2021-09-07 11:30:00-04:00  750.283203  753.159973  749.130005  752.230103
# 2021-09-07 12:30:00-04:00  752.300415  753.349915  750.030029  752.299927
# 2021-09-07 13:30:00-04:00  752.140015  754.839600  751.727173  752.979980
# 2021-09-07 14:30:00-04:00  752.849976  755.599976  752.309998  753.140015
# 2021-09-07 15:30:00-04:00  753.039978  753.989990  751.289978  752.739990
#
#                             Volume  Dividends  Stock Splits     RSI_14  \
# ...

# %%
# Create your own Custom Strategy
CustomStrategy = ta.Strategy(
    name="Momo and Volatility",
    description="SMA 50,200, BBANDS, RSI, MACD and Volume SMA 20",
    ta=[
        {"kind": "sma", "length": 50},
        {"kind": "sma", "length": 200},
        {"kind": "bbands", "length": 20},
        {"kind": "rsi"},
        {"kind": "macd", "fast": 8, "slow": 21},
        {"kind": "sma", "close": "volume", "length": 20, "prefix": "VOLUME"},
    ]
)
# To run your "Custom Strategy"
df.ta.strategy(CustomStrategy)

# %%
df.ta.percent_return(cumulative=True).plot()
# Out:
# <AxesSubplot:>
