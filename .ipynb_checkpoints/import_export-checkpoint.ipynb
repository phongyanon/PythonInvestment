# %%
import pandas as pd

# %%
oil = pd.read_csv('Oil.csv')

# %%
oil
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0     11/4/2016  39.720001  40.750000  39.250000  40.360001  40.360001
# 1     12/4/2016  40.349998  42.250000  40.090000  42.169998  42.169998
# 2     13/4/2016  41.630001  42.419998  41.240002  41.759998  41.759998
# 3     14/4/2016  41.540001  42.160000  40.840000  41.500000  41.500000
# 4     15/4/2016  41.430000  41.730000  39.980000  40.360001  40.360001
# ...         ...        ...        ...        ...        ...        ...
# 1252   2/4/2021  61.450001  61.450001  61.450001  61.450001  61.450001
# 1253   5/4/2021  61.500000  61.500000  57.630001  58.650002  58.650002
# 1254   6/4/2021  58.799999  60.900002  58.619999  59.330002  59.330002
# 1255   7/4/2021  59.259998  60.040001  58.119999  59.770000  59.770000
# 1256   8/4/2021  59.520000  59.930000  58.820000  59.599998  59.599998
#
#         Volume
# 0     679351.0
# 1     796837.0
# 2     730437.0
# 3     488614.0
# 4     520146.0
# ...        ...
# 1252  605567.0
# 1253  438864.0
# 1254  457348.0
# 1255  475537.0
# 1256  475537.0
#
# [1257 rows x 7 columns]

# %%
oil.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
oil = pd.read_csv('Oil.csv', index_col='Date')

# oil = pd.read_csv('Oil.csv')
# oil = oil.set_index('Date')

# %%
# oil_xlsx = pd.read_excel('Oil.xlsx')
# oil_xlsx = pd.read_excel('Oil.xlsx' sheet_name=['CVX'])

# %%
# oil_xlsx['Oil']
# oil_xlsx['CVX']

# %%
import pandas_datareader as web

start = '2020-01-01'
end = '2021-01-01'

# %%
tsla = web.get_data_yahoo('TSLA', start=start, end=end)
tsla
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-12-31   84.258003   80.416000   81.000000   83.666000  51428500.0
# 2020-01-02   86.139999   84.342003   84.900002   86.052002  47660500.0
# 2020-01-03   90.800003   87.384003   88.099998   88.601997  88892500.0
# 2020-01-06   90.311996   88.000000   88.094002   90.307999  50665000.0
# 2020-01-07   94.325996   90.671997   92.279999   93.811996  89410500.0
# ...                ...         ...         ...         ...         ...
# 2020-12-24  666.090027  641.000000  642.989990  661.770020  22865600.0
# 2020-12-28  681.400024  660.799988  674.510010  663.690002  32278600.0
# 2020-12-29  669.900024  655.000000  661.000000  665.989990  22910800.0
# 2020-12-30  696.599976  668.359985  672.000000  694.780029  42846000.0
# 2020-12-31  718.719971  691.119995  699.989990  705.669983  49649900.0
#
#              Adj Close
# Date
# 2019-12-31   83.666000
# 2020-01-02   86.052002
# 2020-01-03   88.601997
# 2020-01-06   90.307999
# 2020-01-07   93.811996
# ...                ...
# 2020-12-24  661.770020
# 2020-12-28  663.690002
# 2020-04-30  137.320382  128.212762  133.058952  132.719715  9.082798e+07
# 2020-05-31  163.147200  156.069100  159.812000  159.885102  6.817590e+07
# 2020-06-30  196.173181  187.734000  191.638728  192.708453  5.813016e+07
# 2020-07-31  303.024820  281.311821  292.988002  292.028179  8.605307e+07
# 2020-08-31  367.357906  346.349333  354.512284  360.059711  7.416088e+07
# 2020-09-30  428.257618  395.665713  414.282859  413.495239  8.268023e+07
# 2020-10-31  436.831822  421.228180  430.490458  427.209545  3.789393e+07
# 2020-11-30  476.083501  453.335501  464.273001  465.612498  3.912994e+07
# 2020-12-31  647.822726  615.457725  631.504095  638.818640  5.437936e+07
#
#              Adj Close
# Date
# 2019-12-31   83.666000
# 2020-01-31  105.731809
# 2020-02-29  159.489368
# 2020-03-31  111.820273
# 2020-04-30  132.719715
# 2020-05-31  159.885102
# 2020-06-30  192.708453
# 2020-07-31  292.028179
# 2020-08-31  360.059711
# 2020-09-30  413.495239
# 2020-10-31  427.209545
# 2020-11-30  465.612498
# 2020-12-31  638.818640

# %%
import quandl

# %%
quandl.ApiConfig.api_key = 'API_Keys'

# %%
msft = quandl.get('EOD/MSFT', start_date=start, end_date=end)
msft
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-16-b2e032c4c768> in <module>
# ----> 1 msft = quandl.get('EOD/MSFT', start_date=start, end_date=end)
#       2 msft
#
# ~\anaconda3\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\anaconda3\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# ~\anaconda3\lib\site-packages\quandl\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      48                                        **options)
#      49             if response.status_code < 200 or response.status_code >= 300:
# ---> 50                 cls.handle_api_error(response)
#      51             else:
#      52                 return response
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     112         klass = d_klass.get(code_letter, QuandlError)
#     113
# --> 114         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# AuthenticationError: (Status 400) (Quandl Error QEAx01) We could not recognize your API key: API_Keys. Please check your API key and try again. You can find your API key under your account settings.

# %%
data = quandl.get_table('WIKI/PRICES', ticker = ['AAPL'],
                        qopts = {'columns' : ['ticker', 'date', 'adj_close']},
                        data = {'gte' : '2016-01-01', 'lte' : '2021-01-01'},
                        paginate = True)
data
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# <ipython-input-17-519ffd4b4b77> in <module>
# ----> 1 data = quandl.get_table('WIKI/PRICES', ticker = ['AAPL'],
#       2                         qopts = {'columns' : ['ticker', 'date', 'adj_close']},
#       3                         data = {'gte' : '2016-01-01', 'lte' : '2021-01-01'},
#       4                         paginate = True)
#
# ~\anaconda3\lib\site-packages\quandl\get_table.py in get_table(datatable_code, **options)
#      17     while True:
#      18         next_options = copy.deepcopy(options)
# ---> 19         next_data = Datatable(datatable_code).data(params=next_options)
#      20
#      21         if data is None:
#
# ~\anaconda3\lib\site-packages\quandl\model\datatable.py in data(self, **options)
#      29         if not options:
#      30             options = {'params': {}}
# ---> 31         return Data.page(self, **options)
#      32
#      33     def download_file(self, file_or_folder_path, **options):
#
# ~\anaconda3\lib\site-packages\quandl\operations\list.py in page(cls, datatable, **options)
#      28         updated_options = Util.convert_options(request_type=request_type, **options)
#      29
# ---> 30         r = Connection.request(request_type, path, **updated_options)
#      31
#      32         response_data = r.json()
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      48                                        **options)
#      49             if response.status_code < 200 or response.status_code >= 300:
# ---> 50                 cls.handle_api_error(response)
#      51             else:
#      52                 return response
#
# ~\anaconda3\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     112         klass = d_klass.get(code_letter, QuandlError)
#     113
# --> 114         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# InvalidRequestError: (Status 422) (Quandl Error QESx08) You cannot use data column as a filter.

# %%
df = data.iloc[::-1]
df

# %%
import yfinance as yf
tickerSymbol = 'NFLX'

# %%
tickerData = yf.Ticker(tickerSymbol)
tickerDf = tickerData.history(period='1d', start=start, end=end)
tickerDf

# %%
tickerData.calendar

# %%
tickerData.recommendations

# %%
from google.colab import drive
drive.mount('/content/drive')
# follow the url then get auth code
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-19-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
df = pd.read_csv(path) # path from google drive
