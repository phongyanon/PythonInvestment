# %%
import matplotlib
import pandas as pd
from pandas_datareader import data as pdr
import mplfinance as mpf

import yfinance as yf
yf.pdr_override()

# %%
PTT = pdr.get_data_yahoo('PTT.BK', start='2019-01-01', end='2021-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
mpf.plot(PTT)

# %%
mpf.plot(PTT.loc['2020-08': '2021-06'], type='candle', figsize=(20, 10), mav=(10, 20, 50))

# %%
data = PTT.loc['2020-08': '2021-06']

# %%
kwargs = dict(mav=(10, 20, 50), volume=True, type='candle', show_nontrading=False, figsize=(20, 10))

# %%
mpf.plot(data, **kwargs, style='charles')

# %%
mpf.available_styles()
# Out:
# ['binance',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'yahoo']
